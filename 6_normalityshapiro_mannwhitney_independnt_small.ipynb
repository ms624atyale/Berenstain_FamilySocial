# %% [markdown]
# <a href="https://colab.research.google.com/github/ms624atyale/Berenstain_FamilySocial/blob/main/6_normalityshapiro_mannwhitney_independnt_small.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ms624atyale/Berenstain_FamilySocial
# Out:
# Cloning into 'Berenstain_FamilySocial'...
# remote: Enumerating objects: 288, done.
# remote: Counting objects: 100% (165/165), done.
# remote: Compressing objects: 100% (145/145), done.
# remote: Total 288 (delta 100), reused 20 (delta 20), pack-reused 123 (from 1)
# Receiving objects: 100% (288/288), 8.21 MiB | 15.23 MiB/s, done.
# Resolving deltas: 100% (150/150), done.

# %%
# !pip install --upgrade nbformat nbconvert

# %% [markdown]
# ###**[Normality Test] 1. N-plits (word token)**

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

from scipy.stats import shapiro
from scipy.stats import kstest, norm # stats


# Load the data from the CSV file
data = pd.read_csv('/content/Berenstain_FamilySocial/narrative_NSplits_MATTR.csv')
df = data['N_splits']  # Extract the column containing the data


# Perform Shapiro-Wilk test for normality
statistic, p_value = shapiro(data)
print(data)
print('\n')


# Convert the data to a pandas DataFrame
df2 = pd.DataFrame(data, columns=['N_splits']) #🍏
# Display the full set of data points
print("Full set of data points for Non-Gaussian data:")
print(df2)
print('\n')

# Save the DataFrame to a CSV file
df2.to_csv('data_N_Spirts_Shapiro.csv', index=True) #🍏

# Perform Shapiro-Wilk test for normality
statistic, p_value = shapiro(data)

# Print the test statistic and p-value
print("Shapiro-Wilk Test Statistic:", statistic)
print("p-value:", p_value)

# Define the CTT (critical test threshold, aka., alpha)
alpha = 0.05

# Interpret the result
if p_value > alpha:
    print("Sample looks Gaussian (fail to reject H0)")
else:
    print("Sample does not look Gaussian (reject H0)")


# Plot histogram of the data
plt.figure(figsize=(10, 6))
sns.histplot(df, kde=True, color='yellow', stat='density')

# Plot normal distribution curve
mu, sigma = np.mean(df), np.std(df)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, norm.pdf(x, mu, sigma), 'r-', label='Normal Distribution')

plt.xlabel('Data')
plt.ylabel('Density')
plt.title('Histogram of N-Splits Data with Normal Distribution') #🍏
plt.legend()
plt.show()
# Out:
#     narrative  N_splits  MATTR
# 0           1       623  0.781
# 1           1       896  0.745
# 2           1      1267  0.760
# 3           1       787  0.774
# 4           1      1031  0.754
# 5           1      1156  0.798
# 6           1      1306  0.753
# 7           1      1507  0.788
# 8           2       804  0.788
# 9           2      1035  0.785
# 10          2      1153  0.777
# 11          2      1485  0.773
# 12          2      1415  0.756
# 13          2      1255  0.801
# 14          2      1300  0.787
# 15          2      1533  0.792
#
#
# Full set of data points for Non-Gaussian data:
#     N_splits
# 0        623
# 1        896
# 2       1267
# 3        787
# 4       1031
# 5       1156
# 6       1306
# 7       1507
# 8        804
# 9       1035
# 10      1153
# 11      1485
# 12      1415
# 13      1255
# 14      1300
# 15      1533
#
#
# Shapiro-Wilk Test Statistic: 0.6674397320983676
# p-value: 3.6906580955909825e-09
# ...

# %% [markdown]
# ###**[Normality Test] 2.MATTR**

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

from scipy.stats import shapiro
from scipy.stats import kstest, norm # stats


# Load the data from the CSV file
data = pd.read_csv('/content/Berenstain_FamilySocial/narrative_NSplits_MATTR.csv') #🍎
df = data['MATTR']  # Extract the column containing the data #🍏


# Perform Shapiro-Wilk test for normality
statistic, p_value = shapiro(data)
print(data)
print('\n')


# Convert the data to a pandas DataFrame
df2 = pd.DataFrame(data, columns=['MATTR']) #🍏
# Display the full set of data points
print("Full set of data points for Non-Gaussian data:")
print(df2)
print('\n')

# Save the DataFrame to a CSV file
df2.to_csv('data_MATTR_Shapiro.csv', index=True)  #🍏
# Perform Shapiro-Wilk test for normality
statistic, p_value = shapiro(data)

# Print the test statistic and p-value
print("Shapiro-Wilk Test Statistic:", statistic)
print("p-value:", p_value)

# Define the CTT (critical test threshold, aka., alpha)
alpha = 0.05

# Interpret the result
if p_value > alpha:
    print("Sample looks Gaussian (fail to reject H0)")
else:
    print("Sample does not look Gaussian (reject H0)")


# Plot histogram of the data
plt.figure(figsize=(10, 6))
sns.histplot(df, kde=True, color='yellow', stat='density')

# Plot normal distribution curve
mu, sigma = np.mean(df), np.std(df)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, norm.pdf(x, mu, sigma), 'r-', label='Normal Distribution')

plt.xlabel('Data')
plt.ylabel('Density')
plt.title('Histogram of MATTR Data with Normal Distribution') #🍏
plt.legend()
plt.show()
# Out:
#     narrative  N_splits  MATTR
# 0           1       623  0.781
# 1           1       896  0.745
# 2           1      1267  0.760
# 3           1       787  0.774
# 4           1      1031  0.754
# 5           1      1156  0.798
# 6           1      1306  0.753
# 7           1      1507  0.788
# 8           2       804  0.788
# 9           2      1035  0.785
# 10          2      1153  0.777
# 11          2      1485  0.773
# 12          2      1415  0.756
# 13          2      1255  0.801
# 14          2      1300  0.787
# 15          2      1533  0.792
#
#
# Full set of data points for Non-Gaussian data:
#     MATTR
# 0   0.781
# 1   0.745
# 2   0.760
# 3   0.774
# 4   0.754
# 5   0.798
# 6   0.753
# 7   0.788
# 8   0.788
# 9   0.785
# 10  0.777
# 11  0.773
# 12  0.756
# 13  0.801
# 14  0.787
# 15  0.792
#
#
# Shapiro-Wilk Test Statistic: 0.6674397320983676
# p-value: 3.6906580955909825e-09
# Sample does not look Gaussian (reject H0)

# %% [markdown]
# ##**Normality Test for Posive input**

# %% [markdown]
# ### <font color = 'red'> **Shapiro Test for N < 50**

# %% [markdown]
# ### **3. Number of positive sentences**

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

from scipy.stats import shapiro
from scipy.stats import kstest, norm # stats


# Load the data from the CSV file
data = pd.read_csv('/content/Berenstain_FamilySocial/narrative_positive_nsent_ratiosent.csv') #🍎
df = data['Ratio_pos_sent']  # Extract the column containing the data


# Perform Shapiro-Wilk test for normality
statistic, p_value = shapiro(data)
print(data)
print('\n')


# Convert the data to a pandas DataFrame
df2 = pd.DataFrame(data, columns=['N_pos_sent']) #🍏
# Display the full set of data points
print("Full set of data points for Non-Gaussian data:")
print(df2)
print('\n')

# Save the DataFrame to a CSV file
df2.to_csv('data_N_pos_sent.csv', index=True) #🍏

# Perform Shapiro-Wilk test for normality
statistic, p_value = shapiro(data)

# Print the test statistic and p-value
print("Shapiro-Wilk Test Statistic:", statistic)
print("p-value:", p_value)

# Define the CTT (critical test threshold, aka., alpha)
alpha = 0.05

# Interpret the result
if p_value > alpha:
    print("Sample looks Gaussian (fail to reject H0)")
else:
    print("Sample does not look Gaussian (reject H0)")


# Plot histogram of the data
plt.figure(figsize=(10, 6))
sns.histplot(df, kde=True, color='yellow', stat='density')

# Plot normal distribution curve
mu, sigma = np.mean(df), np.std(df)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, norm.pdf(x, mu, sigma), 'r-', label='Normal Distribution')

plt.xlabel('Data')
plt.ylabel('Density')
plt.title('Histogram of N_Positive Sentence Data with Normal Distribution') #🍏
plt.legend()
plt.show()
# Out:
#     narrative  N_pos_sent  Ratio_pos_sent
# 0           1          13       34.210526
# 1           1          28       41.791045
# 2           1          21       21.875000
# 3           1          16       28.571429
# 4           1          16       22.857143
# 5           1          22       32.352941
# 6           1          29       24.576271
# 7           1          33       30.000000
# 8           2          19       33.333333
# 9           2          31       42.465753
# 10          2          39       46.987952
# 11          2          33       27.500000
# 12          2          36       35.294118
# 13          2          43       46.739130
# 14          2          21       23.076923
# 15          2          23       21.495327
#
#
# Full set of data points for Non-Gaussian data:
#     N_pos_sent
# 0           13
# 1           28
# 2           21
# 3           16
# 4           16
# 5           22
# 6           29
# 7           33
# 8           19
# 9           31
# ...

# %% [markdown]
# ### **4. Ratio of positive sentences**

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

from scipy.stats import shapiro
from scipy.stats import kstest, norm # stats


# Load the data from the CSV file
data = pd.read_csv('/content/Berenstain_FamilySocial/narrative_positive_nsent_ratiosent.csv') #🍎
df = data['Ratio_pos_sent']  # Extract the column containing the data #🍏


# Perform Shapiro-Wilk test for normality
statistic, p_value = shapiro(data)
print(data)
print('\n')


# Convert the data to a pandas DataFrame
df2 = pd.DataFrame(data, columns=['Ratio_pos_sent']) #🍏
# Display the full set of data points
print("Full set of data points for Non-Gaussian data:")
print(df2)
print('\n')

# Save the DataFrame to a CSV file
df2.to_csv('data_ration_pos_sent.csv', index=True) #🍏

# Perform Shapiro-Wilk test for normality
statistic, p_value = shapiro(data)

# Print the test statistic and p-value
print("Shapiro-Wilk Test Statistic:", statistic)
print("p-value:", p_value)

# Define the CTT (critical test threshold, aka., alpha)
alpha = 0.05

# Interpret the result
if p_value > alpha:
    print("Sample looks Gaussian (fail to reject H0)")
else:
    print("Sample does not look Gaussian (reject H0)")


# Plot histogram of the data
plt.figure(figsize=(10, 6))
sns.histplot(df, kde=True, color='yellow', stat='density')

# Plot normal distribution curve
mu, sigma = np.mean(df), np.std(df)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, norm.pdf(x, mu, sigma), 'r-', label='Normal Distribution')

plt.xlabel('Data')
plt.ylabel('Density')
plt.title('Histogram of Positive Sentence in % Data with Normal Distribution') #🍏
plt.legend()
plt.show()
# Out:
#     narrative  N_pos_sent  Ratio_pos_sent
# 0           1          13       34.210526
# 1           1          28       41.791045
# 2           1          21       21.875000
# 3           1          16       28.571429
# 4           1          16       22.857143
# 5           1          22       32.352941
# 6           1          29       24.576271
# 7           1          33       30.000000
# 8           2          19       33.333333
# 9           2          31       42.465753
# 10          2          39       46.987952
# 11          2          33       27.500000
# 12          2          36       35.294118
# 13          2          43       46.739130
# 14          2          21       23.076923
# 15          2          23       21.495327
#
#
# Full set of data points for Non-Gaussian data:
#     Ratio_pos_sent
# 0        34.210526
# 1        41.791045
# 2        21.875000
# 3        28.571429
# 4        22.857143
# 5        32.352941
# 6        24.576271
# 7        30.000000
# ...

# %% [markdown]
# ## **[Normality Test] 5. Flesch Reading Ease**

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

from scipy.stats import shapiro
from scipy.stats import kstest, norm # stats


# Load the data from the CSV file
data = pd.read_csv('/content/Berenstain_FamilySocial/Data_Sentiment_Blesch_Frame/narrative_FleshReadingEase.csv')
df = data['FRE']  # Extract the column containing the data


# Perform Shapiro-Wilk test for normality
statistic, p_value = shapiro(data)
print(data)
print('\n')


# Convert the data to a pandas DataFrame
df2 = pd.DataFrame(data, columns=['FRE']) #🍏
# Display the full set of data points
print("Full set of data points for Non-Gaussian data:")
print(df2)
print('\n')

# Save the DataFrame to a CSV file
df2.to_csv('data_FRE_Shapiro.csv', index=True) #🍏

# Perform Shapiro-Wilk test for normality
statistic, p_value = shapiro(data)

# Print the test statistic and p-value
print("Shapiro-Wilk Test Statistic:", statistic)
print("p-value:", p_value)

# Define the CTT (critical test threshold, aka., alpha)
alpha = 0.05

# Interpret the result
if p_value > alpha:
    print("Sample looks Gaussian (fail to reject H0)")
else:
    print("Sample does not look Gaussian (reject H0)")


# Plot histogram of the data
plt.figure(figsize=(10, 6))
sns.histplot(df, kde=True, color='yellow', stat='density')

# Plot normal distribution curve
mu, sigma = np.mean(df), np.std(df)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, norm.pdf(x, mu, sigma), 'r-', label='Normal Distribution')

plt.xlabel('Data')
plt.ylabel('Density')
plt.title('Histogram of FRE Data with Normal Distribution') #🍏
plt.legend()
plt.show()
# Out:
#     narrative        FRE
# 0           1  92.230097
# 1           1  84.047677
# 2           1  82.420864
# 3           1  81.367377
# 4           1  83.850146
# 5           1  80.852446
# 6           1  87.584274
# 7           1  81.368292
# 8           2  83.249074
# 9           2  84.739952
# 10          2  81.252163
# 11          2  81.770188
# 12          2  84.768312
# 13          2  87.283369
# 14          2  85.055343
# 15          2  83.241246
#
#
# Full set of data points for Non-Gaussian data:
#           FRE
# 0   92.230097
# 1   84.047677
# 2   82.420864
# 3   81.367377
# 4   83.850146
# 5   80.852446
# 6   87.584274
# 7   81.368292
# 8   83.249074
# 9   84.739952
# 10  81.252163
# 11  81.770188
# 12  84.768312
# 13  87.283369
# 14  85.055343
# 15  83.241246
#
#
# Shapiro-Wilk Test Statistic: 0.6745692126105396
# p-value: 3.699969635887896e-07
# Sample does not look Gaussian (reject H0)

# %% [markdown]
# #🍉🍉 <font color = 'red'> **Mann-Whitney U Test for N <50 with independent samples**

# %% [markdown]
# ####**1. Mann-Whitney U Test for N_Split**

# %%
import pandas as pd
from scipy.stats import mannwhitneyu
import numpy as np

# Load the data from the CSV file
data = pd.read_csv('/content/Berenstain_FamilySocial/narrative_NSplits_MATTR.csv')

# 'group1' and 'group2' are the columns containing the two groups of data
# Extract the measurements for each group
group1 = data[data['narrative'] == 1]['N_splits']
group2 = data[data['narrative'] == 2]['N_splits']

# Using the mannwhitneyu function from the scipy.stats module,
#it takes two groups of data (group1 and group2) as input and
#performs a two-sided test (i.e., tests whether the distributions of the two groups are different).
U_statistic, p_value = mannwhitneyu(group1, group2, alternative='two-sided')

# Calculate mean and standard deviation for U
n1 = len(group1) #len() calculates the number of observations in group1
n2 = len(group2)
# Calculate the mean of the U statistic under the null hypothesis of no difference between the two groups.
#It's calculated as the product of the sample sizes divided by 2.
mu_U = n1 * n2 / 2
# Calculates the standard deviation of the U statistic under the null hypothesis.
#It's calculated using the formula for the standard deviation of the sum of ranks(순위합계) in the Mann-Whitney U test.
sigma_U = np.sqrt(n1 * n2 * (n1 + n2 + 1) / 12) #constant 12 for the denominator

# Calculate z-score
# measures the number of standard deviations away from the mean that the observed U statistic is.
#It's calculated as the difference between the observed U statistic and
#the expected mean U statistic under the null hypothesis, divided by the standard deviation of U.
z = (U_statistic - mu_U) / sigma_U

# Print the results
print ("Ho: There is no difference in amount of words which children get across different narrative types.")
print("Mann-Whitney U:", U_statistic)
print("p-value:", p_value)
print("z-score:", z)

# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("Interpretation: Data between the two groups are NOT equal. (Reject Ho (p<0.05*))")
else:
    print("Interpretation: Data between the two groups are equal. (Fail to reject Ho (p>0.05*))")
# Out:
# Ho: There is no difference in amount of words which children get across different narrative types.
# Mann-Whitney U: 21.0
# p-value: 0.2786324786324786
# z-score: -1.155231069323108
# Interpretation: Data between the two groups are equal. (Fail to reject Ho (p>0.05*))

# %% [markdown]
# ####**2. Mann-Whitney U Test for MATTR**

# %%
import pandas as pd
from scipy.stats import mannwhitneyu
import numpy as np

# Load the data from the CSV file
data = pd.read_csv('/content/Berenstain_FamilySocial/narrative_NSplits_MATTR.csv')

# 'group1' and 'group2' are the columns containing the two groups of data
# Extract the measurements for each group
group1 = data[data['narrative'] == 1]['MATTR']
group2 = data[data['narrative'] == 2]['MATTR']

# Using the mannwhitneyu function from the scipy.stats module,
#it takes two groups of data (group1 and group2) as input and
#performs a two-sided test (i.e., tests whether the distributions of the two groups are different).
U_statistic, p_value = mannwhitneyu(group1, group2, alternative='two-sided')

# Calculate mean and standard deviation for U
n1 = len(group1) #len() calculates the number of observations in group1
n2 = len(group2)
# Calculate the mean of the U statistic under the null hypothesis of no difference between the two groups.
#It's calculated as the product of the sample sizes divided by 2.
mu_U = n1 * n2 / 2
# Calculates the standard deviation of the U statistic under the null hypothesis.
#It's calculated using the formula for the standard deviation of the sum of ranks(순위합계) in the Mann-Whitney U test.
sigma_U = np.sqrt(n1 * n2 * (n1 + n2 + 1) / 12) #constant 12 for the denominator

# Calculate z-score
# measures the number of standard deviations away from the mean that the observed U statistic is.
#It's calculated as the difference between the observed U statistic and
#the expected mean U statistic under the null hypothesis, divided by the standard deviation of U.
z = (U_statistic - mu_U) / sigma_U

# Print the results
print ("Ho: There is no difference in lexical diversity which children get across different narrative types.")
print("Mann-Whitney U:", U_statistic)
print("p-value:", p_value)
print("z-score:", z)

# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("Interpretation: Data between the two groups are NOT equal. (Reject Ho (p<0.05*))")
else:
    print("Interpretation: Data between the two groups are equal. (Fail to reject Ho (p>0.05*))")
# Out:
# Ho: There is no difference in lexical diversity which children get across different narrative types.
# Mann-Whitney U: 18.5
# p-value: 0.1718517022196694
# z-score: -1.41778358507836
# Interpretation: Data between the two groups are equal. (Fail to reject Ho (p>0.05*))

# %% [markdown]
# Normality test and for Sentiment analysis focusing positive sentences

# %% [markdown]
# Non-Gaussian, thus Mann_Whitney U Test since we are dealing with independent samples

# %% [markdown]
# ####**3. Mann-Whitney U Test for Numbrer of positive sentence-level tokens**

# %%
import pandas as pd
from scipy.stats import mannwhitneyu
import numpy as np

# Load the data from the CSV file
data = pd.read_csv('/content/Berenstain_FamilySocial/narrative_positive_nsent_ratiosent.csv')

# 'group1' and 'group2' are the columns containing the two groups of data
# Extract the measurements for each group
group1 = data[data['narrative'] == 1]['N_pos_sent']
group2 = data[data['narrative'] == 2]['N_pos_sent']

# Using the mannwhitneyu function from the scipy.stats module,
#it takes two groups of data (group1 and group2) as input and
#performs a two-sided test (i.e., tests whether the distributions of the two groups are different).
U_statistic, p_value = mannwhitneyu(group1, group2, alternative='two-sided')

# Calculate mean and standard deviation for U
n1 = len(group1) #len() calculates the number of observations in group1
n2 = len(group2)
# Calculate the mean of the U statistic under the null hypothesis of no difference between the two groups.
#It's calculated as the product of the sample sizes divided by 2.
mu_U = n1 * n2 / 2
# Calculates the standard deviation of the U statistic under the null hypothesis.
#It's calculated using the formula for the standard deviation of the sum of ranks(순위합계) in the Mann-Whitney U test.
sigma_U = np.sqrt(n1 * n2 * (n1 + n2 + 1) / 12) #constant 12 for the denominator

# Calculate z-score
# measures the number of standard deviations away from the mean that the observed U statistic is.
#It's calculated as the difference between the observed U statistic and
#the expected mean U statistic under the null hypothesis, divided by the standard deviation of U.
z = (U_statistic - mu_U) / sigma_U

# Print the results
print ("Ho: There is no difference in exposing children to positive sentences depending on different narrative types.")
print("Mann-Whitney U:", U_statistic)
print("p-value:", p_value)
print("z-score:", z)

# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("Interpretation: Data between the two groups are NOT equal. (Reject Ho (p<0.05*))")
else:
    print("Interpretation: Data between the two groups are equal. (Fail to reject Ho (p>0.05*))")
# Out:
# Ho: There is no difference in exposing children to positive sentences depending on different narrative types.
# Mann-Whitney U: 14.0
# p-value: 0.06548462989319012
# z-score: -1.8903781134378133
# Interpretation: Data between the two groups are equal. (Fail to reject Ho (p>0.05*))

# %% [markdown]
# ####**4. Mann-Whitney U Test for Ratio_positive_sent in %**

# %%
# 'group1' and 'group2' are the columns containing the two groups of data
# Extract the measurements for each group
group1 = data[data['narrative'] == 1]['Ratio_pos_sent']
group2 = data[data['narrative'] == 2]['Ratio_pos_sent']

# Using the mannwhitneyu function from the scipy.stats module,
#it takes two groups of data (group1 and group2) as input and
#performs a two-sided test (i.e., tests whether the distributions of the two groups are different).
U_statistic, p_value = mannwhitneyu(group1, group2, alternative='two-sided')

# Calculate mean and standard deviation for U
n1 = len(group1) #len() calculates the number of observations in group1
n2 = len(group2)
# Calculate the mean of the U statistic under the null hypothesis of no difference between the two groups.
#It's calculated as the product of the sample sizes divided by 2.
mu_U = n1 * n2 / 2
# Calculates the standard deviation of the U statistic under the null hypothesis.
#It's calculated using the formula for the standard deviation of the sum of ranks(순위합계) in the Mann-Whitney U test.
sigma_U = np.sqrt(n1 * n2 * (n1 + n2 + 1) / 12) #constant 12 for the denominator

# Calculate z-score
# measures the number of standard deviations away from the mean that the observed U statistic is.
#It's calculated as the difference between the observed U statistic and
#the expected mean U statistic under the null hypothesis, divided by the standard deviation of U.
z = (U_statistic - mu_U) / sigma_U

# Print the results
print ("Ho: There is no difference in exposing children to positive sentences in % depending on different narrative types.")
print("Mann-Whitney U:", U_statistic)
print("p-value:", p_value)
print("z-score:", z)

# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("Interpretation: Data between the two groups are NOT equal. (Reject Ho (p<0.05*))")
else:
    print("Interpretation: Data between the two groups are equal. (Fail to reject Ho (p>0.05*))")
# Out:
# Ho: There is no difference in exposing children to positive sentences in % depending on different narrative types.
# Mann-Whitney U: 22.0
# p-value: 0.32820512820512815
# z-score: -1.0502100630210074
# Interpretation: Data between the two groups are equal. (Fail to reject Ho (p>0.05*))

# %% [markdown]
# ## **[Mann-Whitney U Test] 5. Flesch Reading Ease**

# %%
import pandas as pd
from scipy.stats import mannwhitneyu
import numpy as np

# Load the data from the CSV file
data = pd.read_csv('/content/Berenstain_FamilySocial/Data_Sentiment_Blesch_Frame/narrative_FleshReadingEase.csv') #🍎

# 'group1' and 'group2' are the columns containing the two groups of data
# Extract the measurements for each group
group1 = data[data['narrative'] == 1]['FRE'] #🍏
group2 = data[data['narrative'] == 2]['FRE'] #🍏

# Using the mannwhitneyu function from the scipy.stats module,
#it takes two groups of data (group1 and group2) as input and
#performs a two-sided test (i.e., tests whether the distributions of the two groups are different).
U_statistic, p_value = mannwhitneyu(group1, group2, alternative='two-sided')

# Calculate mean and standard deviation for U
n1 = len(group1) #len() calculates the number of observations in group1
n2 = len(group2)
# Calculate the mean of the U statistic under the null hypothesis of no difference between the two groups.
#It's calculated as the product of the sample sizes divided by 2.
mu_U = n1 * n2 / 2
# Calculates the standard deviation of the U statistic under the null hypothesis.
#It's calculated using the formula for the standard deviation of the sum of ranks(순위합계) in the Mann-Whitney U test.
sigma_U = np.sqrt(n1 * n2 * (n1 + n2 + 1) / 12) #constant 12 for the denominator

# Calculate z-score
# measures the number of standard deviations away from the mean that the observed U statistic is.
#It's calculated as the difference between the observed U statistic and
#the expected mean U statistic under the null hypothesis, divided by the standard deviation of U.
z = (U_statistic - mu_U) / sigma_U

# Print the results
print ("Ho: There is no difference in degree of reading ease using Flesch Reading Ease between Different Narratives.") #🍏
print("Mann-Whitney U:", U_statistic)
print("p-value:", p_value)
print("z-score:", z)

# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("Interpretation: Data between the two groups are NOT equal. (Reject Ho (p<0.05*))")
else:
    print("Interpretation: Data between the two groups are equal. (Fail to reject Ho (p>0.05*))")
# Out:
# Ho: There is no difference in degree of reading ease using Flesch Reading Ease between Different Narratives.
# Mann-Whitney U: 28.0
# p-value: 0.7209013209013208
# z-score: -0.42008402520840293
# Interpretation: Data between the two groups are equal. (Fail to reject Ho (p>0.05*))
