# %% [markdown]
# <a href="https://colab.research.google.com/github/ms624atyale/Berenstain_FamilySocial/blob/main/1_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1️⃣ <font color = 'red'> 🐹🐾 **Final Script to prepare input text for further analysis (e.g., Wordcloud, Lexical Diversity, etc.)**
#
#   - # <font color = 'blue'> 🐹🐾 **Important & Useful!**
#   - ### **This script is based on plain text for "The tale of Benjamin Bunny by Beatrix Potter" under the Repository of "PictureBook_Project_Demo_2025".**

# %%
! git clone https://github.com/ms624atyale/Berenstain_FamilySocial  #Make copy of the whole repository of a github account.
# Out:
# Cloning into 'Berenstain_FamilySocial'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 53 (delta 22), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (53/53), 102.78 KiB | 4.67 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %% [markdown]
# ##<font color = 'red'> 🆘 **ALERT**
# ## <font color = 'red'> 🆘 **Important & Useful!**
#
# ## ⤵️ In order to avoid setting a new repository being created as a subdirectory of the old one
#
# ### <font color = 'blue'> <Python code>
# ### <font color = 'blue'> %cd /content  # Moves to the default root directory in Google Colab
#
# ## ⤵️ In order to delete the old directory forcefully
#
# ### <font color = 'blue'> **▶️ Python code**
# ### <font color = 'gray'> **import shutil**
#
# ### <font color = 'gray'> **shutil.rmtree('/CurrentDirectoryPath')**

# %% [markdown]
# #2️⃣ 🐹🐾 **Set up the current directory**

# %%
# %cd /content/Berenstain_FamilySocial
# Out:
# /content/Berenstain_FamilySocial

# %% [markdown]
# #3️⃣ 🐹🐾 **Read the txt file**

# %%
# ▶️ Step 1: You need to modify this codeline 🍎🍎🍎🍎🍎
file = open("/content/Berenstain_FamilySocial/Data_UTF8/BerenstainBears_EightCopies_Family_UTF8.txt", 'rt')

txt = file.read()
print(txt)
file.close() #Using this close()function, you are no longer using your text file of the current workingdirectory with open()function.
# Out:
# 1. 1974 New Baby
# ...

# %% [markdown]
# #4️⃣ 🐹🐾 **Install NLTK and Download necessary models**

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# # 5️⃣ 🐹🐾 **Just checking with tokenizing sentences**

# %%
from nltk.tokenize import sent_tokenize
sentence = sent_tokenize(txt)
print('Sentence Tokenized: %s' %sentence)
# Out:
# Sentence Tokenized: ['1.', '1974 New Baby  \nDown a sunny dirt road, over a log bridge, up a grassy hill, deep in Bear Country, lived a family of bears—Papa Bear, Mama Bear and Small Bear.', 'They lived in a large tree which Papa Bear had hollowed out and made into a house.', 'It was a very fine house.', 'This is what it looked like inside.', 'It was fun growing up in Bear Country...helping Papa get honey from the old bee tree...helping Mama bring the vegetables in from the garden.', 'There were all sorts of interesting things for a small bear to do and see in Bear-Country.', 'Small Bear felt good growing up in a tree...in his own room...in the snug little bed that Papa Bear had made for him when he was a baby.', 'But one morning, it did not feel so good.', 'Small Bear woke up with pains in his knees and aches in his legs.', '“Small Bear, you have outgrown your little bed,” said Papa Bear, as he hitched up his overalls and buttoned his shoulder straps.', '“Today, we shall go out into
# ...

# %% [markdown]
# # 6️⃣-1️⃣ 📍📍 **Apply a series of functions for replacement**

# %%
import re

# Step 1: Read file to change path as needed 🍎🍎🍎🍎🍎🍎
with open("/content/Berenstain_FamilySocial/Data_UTF8/BerenstainBears_EightCopies_Family_UTF8.txt", 'rt') as fl:
    raw_text = fl.read()

# STEP 2-1: Clean the text
clean_text = (
    raw_text
    .lower()
    .replace("\n", " ")
    .replace("“", "")
    .replace("”", "")
    .replace("\"", "")
    .replace("_", "")
    .replace("[illustration]", "")
    .replace("*", "")
    .replace("?", "")
    .replace("!", "")
    .replace(":", " ")
    .replace(";", "")
    .replace(".", "")
    .replace("...—", " ")
    .replace("—", " ")
    .replace(",", "")
    .replace("(", "")
    .replace(")", "")
)

# STEP 3: Save the cleaned content to a NEW file as you designate the output path 🍏🍏🍏🍏🍏🍏
output_path = "/content/Berenstain_FamilySocial/Data_Clean/Berenstain_EightCopies_Family_Cleaned.txt"
with open(output_path, 'w') as cf:
    cf.write(clean_text) #Get content named 'clean_text' to the new empty file

# Optional: Print to verify
print("✅ Cleaned text saved to:", output_path)
# Out:
# ✅ Cleaned text saved to: /content/Berenstain_FamilySocial/Data_Clean/Berenstain_EightCopies_Family_Cleaned.txt

# %% [markdown]
# ##7️⃣ 🐹🐾 **Dlownload .txt file(s) created under the Data_Clean folder to the relevant directory (e.g., Data_Clean) of your github account**

# %% [markdown]
# # 8️⃣ 🐹🐾 **Just cheking the result file with cleaning applied**
# - **Sentence Tokenization**
# - **Tokenizing Words with Regular Tokenizer**
# - **Get tokenized words put in sequence**

# %%
from nltk.tokenize import sent_tokenize

sentence = sent_tokenize(clean_text)
print('Sentence Tokenized: %s' %sentence)

from nltk.tokenize import RegexpTokenizer #RegexpTokenizer as a class
import re

tok = RegexpTokenizer("[\w]+") # Alert: You cannot use RegexpTokenizer() without argument. You need a regexpression formula.

tk = tok.tokenize(clean_text)
print('Tokenizing Words with RegexpTokenizer: %s' %tk)

print(' '.join(tk)) #small characters
#alternatively, use the codeline of ' '.join(tkn)
# Out:
# Sentence Tokenized: ["1 1974 new baby   down a sunny dirt road over a log bridge up a grassy hill deep in bear country lived a family of bears papa bear mama bear and small bear they lived in a large tree which papa bear had hollowed out and made into a house it was a very fine house this is what it looked like inside it was fun growing up in bear countryhelping papa get honey from the old bee treehelping mama bring the vegetables in from the garden there were all sorts of interesting things for a small bear to do and see in bear-country small bear felt good growing up in a treein his own roomin the snug little bed that papa bear had made for him when he was a baby but one morning it did not feel so good small bear woke up with pains in his knees and aches in his legs small bear you have outgrown your little bed said papa bear as he hitched up his overalls and buttoned his shoulder straps today we shall go out into the woods and make you a bigger one with that he ate his breakfast of
# ...

# %% [markdown]
# #⚠️ <font color = 'green'>**This is the end of the Script! You did a good job!** **
